# %% [markdown]
# <h2>1) 언어 모델(Language Model)이란?</h2>

# %% [markdown]
# <p>
#     1. 단어 시퀀스에 확률을 할당하는 일을 하는 모델입니다.<br>
#     2. 가장 자연스러운 단어 시퀀스를 찾아내는 모델입니다.<br>
#     3. 이전 단어들이 주어졌을 때 다음 단어를 예측하도록 하는 것이 가장 보편적으로 사용되는 언어모델
# </p>

# %% [markdown]
# <b>언어 모델링 : 주어진 단어들로부터 아직 모르는 단어를 예측하는 작업</b>

# %%
from IPython.display import Image

# %% [markdown]
# <h3>3. 주어진 이전 단어들로부터 다음 단어 예측하기</h3>

# %% [markdown]
# <h4>A. 단어 시퀀스의 확률</h4>

# %% [markdown]
# <p>하나의 단어를 w, 단어 시퀀스를 W, n개의 단어가 등장하는 단어 시퀀스 W확률</p>

# %%
Image("wordseq.PNG")

# %% [markdown]
# <h4>B. 다음 단어 등장 확률</h4>

# %% [markdown]
# <p>n-1개의 단어가 나열된 상태에서 n번째 단어의 확률</p>

# %%
Image("nextword.PNG")

# %% [markdown]
# <h2>2) 통계적 언어 모델(Statistical Language Model, SLM)</h2>

# %% [markdown]
# <b>언어 모델의 전통적인 접근 방법</b>

# %% [markdown]
# <h3>1. 조건부 확률</h3>

# %%
Image("SLM_IF.PNG")

# %% [markdown]
# <h3>2. 문장에 대한 확률</h3>

# %% [markdown]
# <b>조건부 확률을 사용, 조건부 확률의 일반화 식을 문장의 확률 관점에서 다시 적음</b>

# %%
Image("Ques.PNG")

# %% [markdown]
# <h3>3. 카운트 기반의 접근</h3>

# %%
Image("CountAccess.PNG")

# %% [markdown]
# <h3>4. 카운트 기반 접근의 한계 - 희소 문제(Sparsity Problem)</h3>

# %%
Image("CountSparsity.PNG")
