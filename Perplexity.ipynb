# %% [markdown]
# <h2>5) 펄플렉서터(perplexity)</h2>

# %% [markdown]
# <b>모델 내에서 자신의 성능을 수치화하여 결과를 내놓는 내부 평가에 해당하는 방법</b>

# %% [markdown]
# <h3>1. 언어 모델의 평가 방법(Evaluation metric) : PPL.</h3>

# %% [markdown]
# <p>
#     언어 모델을 평가하기 위한 내부 평가 지표입니다.<br>
#     PPL은 수치가 <b>'낮을수록'</b> 언어 모델의 성능이 좋다는 것을 의미한다는 점입니다.
# <p>

# %% [markdown]
# <p>
#     PPL은 단어의 수로 정규화된 테스트 데이터에 대한 확률의 역수입니다.<br>
#     PPL을 최소화한다는 것은 문장의 확률을 최대화하는 것과 같습니다.<br>
#     문장 W의 길이가 N이라고 하였을 때의 PPL은 다음과 같습니다.
# </p>

# %%
from IPython.display import Image

# %%
Image("perplexity.PNG")

# %% [markdown]
# <h3>2. 분기 계수(Branching factor)</h2>

# %% [markdown]
# <p>PPL은 선택할 수 있는 가능한 경우의 수를 의미하는 분기계수</p>

# %% [markdown]
# <b>예를 들어 언어 모델에 어떤 테스트 데이터를 주고 측정했더니 PPL이 10이나왔다.<br>
#     그렇다면 해당 언어 모델은 테스트 데이터에 대해서 다음 단어를 예측하는<br> 모든 시점마다 평균적으로 10개의 단어를 가지고 어떤 것이 정답인지 고민하고 있다고 볼 수 있습니다.

# %%
from IPython.display import Image

# %%
Image('ppltest.PNG')

# %% [markdown]
# <b>PPL의 값이 낮다는 것은 테스트 데이터 상에서 높은 정확도를 보인다는 것이지, <br>
# 사람이 직접 느끼기에 좋은 언어 모델이라는 것을 반드시 의미하진 않는다는 점입니다.

# %% [markdown]
# <b>정량적으로 양이 많고, 도메인에 알맞은 동일한 테스트 데이터를 사용해야 신뢰도가 높다는 것입니다.</b>

# %% [markdown]
# <h3>3. 기존 언어 모델 Vs. 인공 신경망을 이용한 언어 모델.</h3>

# %%
Image('model.PNG')
