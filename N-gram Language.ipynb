# %% [markdown]
# <h2>3) N-gram 언어 모델(N-gram Language Model)</h2>

# %% [markdown]
# <b>
#     1. 카운트에 기반한 통계적 접근을 사용, SLM의 일종입니다.<br>
#     2. 모든 단어를 고려하는 것이 아니라 일부 단어만 고려하는 접근방법<br>
#     3. 일부 단어를 몇 개 보느냐를 결정하는데 이것이 n-gram에서의 n이 가지는 의미
# </b>

# %% [markdown]
# <h3>1. 코퍼스에서 카운트하지 못하는 경우의 감소.</h3>

# %% [markdown]
# <p>확률 계산을 할때 그 문장이 존재하지 않을 가능성이 높다, 그림과 같이 참고하는 단어들을 줄이면 카운트를 할 수 있을 가능성이 높일 수 있다.</p>

# %%
from IPython.display import Image

# %%
Image("N-gramo.PNG")

# %% [markdown]
# <h3>2. N-gram</h3>

# %% [markdown]
# <b>임의의 개수를 정하기 위한 기준을 위해 사용한다.<br>
# 코퍼스에서 n개의 단어 뭉치단위로 끊어서 이를 하나의 토큰으로 간주합니다.</br>

# %% [markdown]
# <p>An adorable little boy is spreading smiles 의 n-gram은</p>

# %%
from IPython.display import Image

# %%
Image("N-gramt.PNG")

# %% [markdown]
# <b>
#     예를 들어 <i>'An adorable little boy is spreading'</i> 다음 단어를 예측하고 싶다면<br>
#     n = 4라고 한 4-gram을 사용한다고 가정할때, 밑의 그림처럼 n-1에 해당되는<br>
#     앞의 3개의 단어만을 고려합니다.
# </b>

# %%
Image("N-gramtr.PNG")
